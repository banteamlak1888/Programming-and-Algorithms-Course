# %% [markdown]
# <a href="https://colab.research.google.com/github/banteamlak1888/Programming-and-Algorithms-Course/blob/main/cluster_algorthim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Visualize the final clusters
plt.figure(figsize=(6, 4))
sns.scatterplot(x=X[:, 1], y=X[:, 0], hue=final_labels, palette='coolwarm', legend='full')

sns.scatterplot( palette='viridis', s=200)

plt.scatter(final_centroids[:, 1], final_centroids[:, 0], color='red', marker='x', s=100, label='Centroids')
plt.title(f'K-Means Clustering (k={optimal_k})')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-692699fbad57> in <cell line: 2>()
#       1 # Visualize the final clusters
# ----> 2 plt.figure(figsize=(6, 4))
#       3 sns.scatterplot(x=X[:, 1], y=X[:, 0], hue=final_labels, palette='coolwarm', legend='full')
#       4
#       5 sns.scatterplot( palette='viridis', s=200)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the final clusters
plt.figure(figsize=(6, 4))
sns.scatterplot(x=X[:, 1], y=X[:, 0], hue=final_labels, palette='coolwarm', legend='full')

sns.scatterplot(palette='viridis', s=200)

plt.scatter(final_centroids[:, 1], final_centroids[:, 0], color='red', marker='x', s=100, label='Centroids')
plt.title(f'K-Means Clustering (k={optimal_k})')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-feb277afb7d2> in <cell line: 6>()
#       4 # Visualize the final clusters
#       5 plt.figure(figsize=(6, 4))
# ----> 6 sns.scatterplot(x=X[:, 1], y=X[:, 0], hue=final_labels, palette='coolwarm', legend='full')
#       7
#       8 sns.scatterplot(palette='viridis', s=200)
#
# NameError: name 'X' is not defined

# %%
# !pip install the_module_where_x_is_defined
# Out:
# ERROR: Could not find a version that satisfies the requirement the_module_where_x_is_defined (from versions: none)
# ERROR: No matching distribution found for the_module_where_x_is_defined

# %%
import sys
sys.path.append('/path/to/the/module')

# %%
import the_module_where_x_is_defined

# Visualize the final clusters
plt.figure(figsize=(6, 4))
sns.scatterplot(x=the_module_where_x_is_defined.X[:, 1], y=the_module_where_x_is_defined.X[:, 0], hue=final_labels, palette='coolwarm', legend='full')

sns.scatterplot(palette='viridis', s=200)

plt.scatter(final_centroids[:, 1], final_centroids[:, 0], color='red', marker='x', s=100, label='Centroids')
plt.title(f'K-Means Clustering (k={optimal_k})')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-a83212556692> in <cell line: 1>()
# ----> 1 import the_module_where_x_is_defined
#       2
#       3 # Visualize the final clusters
#       4 plt.figure(figsize=(6, 4))
#       5 sns.scatterplot(x=the_module_where_x_is_defined.X[:, 1], y=the_module_where_x_is_defined.X[:, 0], hue=final_labels, palette='coolwarm', legend='full')
#
# ModuleNotFoundError: No module named 'the_module_where_x_is_defined'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
